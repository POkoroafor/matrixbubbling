# %% [markdown]
# # Matrix Bubbling

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# This file contains all the main external libs we'll use
# We'll assume you already have numpy and opencv installed
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Utility Functions
def draw_with_size(image, size_in_inches):
    plt.figure(figsize=(size_in_inches, size_in_inches))
    plt.imshow(image);
def random_image(shape):
    return np.random.uniform(0, 1, size=shape).astype(np.float32)
def scale_match(src, targ):
    """Returns the targ image resized so that its at exactly as big as src, while maintaining its aspect ratio.
    This may mean that the right or the bottom may be cropped."""
    h,w,_ = src.shape
    sh,sw,_ = targ.shape
    ratio = max(h/sh,w/sw);
    res = cv2.resize(targ, (int(sw*ratio), int(sh*ratio)))
    return res[:h,:w]

# %% [markdown]
# ## Some Morphological Operations
#
# Morphological operations apply a structuring element to an input image, creating an output image of the same size. In a morphological operation, the value of each pixel in the output image is based on a comparison of the corresponding pixel in the input image with its neighbors. By choosing the size and shape of the neighborhood, you can construct a morphological operation that is sensitive to specific shapes in the input image.
#
# We'll use the following morphological operations to try to mimick real life transformations to images.

# %% [markdown]
# ### Dilation and Erosion
#
# Dilation adds pixels to the boundaries of objects in an image, while erosion removes pixels on object boundaries. The number of pixels added or removed from the objects in an image depends on the size and shape of the structuring element used to process the image. In the morphological dilation and erosion operations, the state of any given pixel in the output image is determined by applying a rule to the corresponding pixel and its neighbors in the input image. The rule used to process the pixels defines the operation as a dilation or an erosion.
# References - https://www.mathworks.com/help/images/morphological-dilation-and-erosion.html, https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_imgproc/py_morphological_ops/py_morphological_ops.html
#
# *
# Dilation - The value of the output pixel is the maximum value of all the pixels in the input pixel's neighborhood. In a binary image, if any of the pixels is set to the value 1, the output pixel is set to 1.
#
# *
# Erosion - The value of the output pixel is the minimum value of all the pixels in the input pixel's neighborhood. In a binary image, if any of the pixels is set to 0, the output pixel is set to 0.

# %%
# Flower Image
img = cv2.imread('samples/flower.jpg',-1)
draw_with_size(img, 7)
kernel = np.ones((50,50),np.uint8)
# Dilation
dilation = cv2.dilate(img,kernel,iterations = 1)
draw_with_size(dilation, 7)
# Erosion
erosion = cv2.erode(img,kernel,iterations = 1)
draw_with_size(erosion, 7)

# %%
# Flower Image
img = cv2.imread('samples/Writing.jpg',1)
draw_with_size(img, 7)
kernel = np.ones((50,50),np.uint8)
dilation = cv2.dilate(img,kernel,iterations = 1)
draw_with_size(dilation, 7)
erosion = cv2.erode(img,kernel,iterations = 1)
draw_with_size(erosion, 7)

# %% [markdown]
# ### Adding Random Noise

# %%
# Gaussian Noise
image = cv2.imread('samples/small-animal.jpg',-1)
draw_with_size(image, 7)
row,col,ch= image.shape
mean = 0.0
var = 0.01
sigma = var**0.5
gauss = np.array(image.shape)
gauss = np.random.normal(mean,sigma,(row,col,ch))
gauss = gauss.reshape(row,col,ch)
noisy = image + 1000*gauss
draw_with_size(noisy, 7)

# %% [markdown]
# ## Computing Distances
#
# This function computes the distance between two matrices A and B and returns a score. Here, n is a parameter that specifies how many cuts to make along each axis.

# %%
def computeDistance(A, B, n, metric):
    row, col = A.shape
    #print(A,B, A.shape)
    # trim matrix so grids are all the same size
    row -= row % n
    col -= col % n
    dist = 0
    for i in range(row // n):
        for j in range(col // n):
            # gridA = A[n*i:n*i+n][n*j:n*j+n]
            gridA = A[np.ix_(range(n*i,n*i+n), range(n*j,n*j+n))]
            gridB = B[np.ix_(range(n*i,n*i+n), range(n*j,n*j+n))]
            meanA, covA = getSummary(gridA)
            #mean = np.mean(gridA, axis=1)
            #cov = np.cov(gridA, rowvar=0)
            #print()
            #print(gridA)
            #print("current", meanA, covA)
            #print("other",mean, cov)
            # print(covA)
            meanB, covB = getSummary(gridB)
            # print(covB)
            if meanA == [] or meanB == []:
                dist += 0 # ignore this grid since nothing is in it
            else:
                dist += getDist(meanA, covA, meanB, covB, metric)
    return dist

def getSummary(grid):
    # get points in grid as an array
    x = []
    y = []
    row, col = grid.shape
    # print(grid.shape)
    # print(row, col)
    for i in range(row):
        for j in range(col):
            # print(i, j, grid[i][j])
            x += [i for i in range(grid[i][j])]
            y += [j for i in range(grid[i][j])]
    
    if x == [] or y == []:
        return ([],[])
    
    x = np.array(x)
    y = np.array(y)

    xMean = np.mean(x)
    yMean = np.mean(y)
    mean = np.array([xMean, yMean])
    x = x - xMean
    y = y - yMean
    coords = np.vstack([x, y])
    cov = np.cov(coords)
    return (mean.T, cov)

def getDist(meanA, covA, meanB, covB, metric):
    '''Pick which distance metric to use'''
    if metric == "KL":
        return getKLDiv(meanA, covA, meanB, covB)
    if metric == "Hell":
        return getHellDist(meanA, covA, meanB, covB)
    else:
        raise ValueError()

def getKLDiv(meanA, covA, meanB, covB):
    '''A represents the actual distribution and B represents the test distribution'''
    mu = meanB - meanA
    return 0.5 * (np.log(np.linalg.det(covB) / np.linalg.det(covA)) \
                  + mu.T @ np.linalg.inv(covB) @ mu \
                  + np.trace(covA @ np.linalg.inv(covB)) \
                  - 2)

def getHellDist(meanA, covA, meanB, covB):
    mu = meanA - meanB
    return 1 \
           - np.power(np.linalg.det(covA), 0.25) \
           * np.power(np.linalg.det(covA), 0.25) \
           / np.power(np.linalg.det((covA+covB)/2), 0.5) \
           * np.exp(-0.125 * mu.T @ np.linalg.inv((covA+covB)/2) @ mu)

# %%
#test1 = np.array([[1, 2, 3],
#                  [4, 5, 6],
#                  [5, 6, 7],
#                  [5, 7, 8],
#                  [7, 8, 9]])

#test2 = np.array([[0, 5, 3],
#                  [6, 7, 0],
#                  [5, 6, 10],
#                  [9, 0, 8],
#                  [7, 9, 0]])

#mean = np.mean(test1)
#cov = np.cov(test1, rowvar=0)
#print(mean, cov)

# computeDistance()
#for metric in ["Hell", "KL"]:
#    for (A, B) in [(test1, test1), (test1, test2), (test2, test1), (test2, test2)]:
#        a = "test1" if np.array_equal(A, test1) else "test2"
#        b = "test1" if np.array_equal(B, test1) else "test2"
#        print("A: " + a)
#        print("B: " + b)
#        print("metric: " + str(metric))
#        try:
#            print(computeDistance(A, B, 2, metric))
#            print()
#        except:
#            print("Error")
#            print()
#    print("-----------------------")

# %% [markdown]
# Comparing Dilation Distances

# %%
def getFilename(char):
    return 'samples/alphabet_cursive_letter_'+char+'.jpg'

def getTransforms(image):
    #print(image.shape)
    kernel = np.ones((5,5),np.uint8)
    dilation = cv2.dilate(image,kernel,iterations = 1)
    erosion = cv2.erode(image,kernel,iterations = 1)
    kernel2 = np.ones((20,20),np.uint8)
    dilation2 = cv2.dilate(image,kernel2,iterations = 1)
    erosion2 = cv2.erode(image,kernel2,iterations = 1)
    mean, var = 0.0, 0.01
    sigma, guass = var**0.5, np.array(image.shape)
    gauss = np.random.normal(mean,sigma,image.shape)
    gauss = gauss.reshape(image.shape)
    noisy = image + 1000*gauss
    #print(dilation.shape, erosion.shape, dilation2.shape, erosion2.shape, noisy.shape)
    return dilation, erosion, dilation2, erosion2, noisy

def computeDistances(image, images):
    return [computeDistance(img, image, 20, "KL") for img in images]

characters = ['a','b']
base_images = [cv2.imread(getFilename(char),0) for char in characters]
# transformed_images = [images for img in base_images for images in getTransforms(img)]
print(len(base_images))
#for img in base_images:
#    print(img.shape)
#    draw_with_size(img, 3)
#for img in transformed_images:
#    draw_with_size(img, 3)
# 
transformsA = getTransforms(base_images[0])

for metric in ["Hell", "KL"]:
    for i in range(len(transformsA)):
        for j in range(2):
            j_str = "The letter " + ("A" if j == 0 else "B")
            print("A: Transformation #" + str(i))
            print("B: " + j_str)
            print("metric: " + str(metric))
            try:
                print(computeDistance(transformsA[i], base_images[j], 20, metric))
                print()
            except:
                print("Error")
                print()
    print("-----------------------")
# Out:
# 2
# A: Transformation #0
# B: The letter A
# metric: Hell
# /Users/Jacky/Library/Python/3.6/lib/python/site-packages/ipykernel_launcher.py:23: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
# -8.238180413747713
#
# A: Transformation #0
# B: The letter B
# metric: Hell
# 14.71711913617127
#
# A: Transformation #1
# B: The letter A
# metric: Hell
# 24.20005807307284
#
# A: Transformation #1
# B: The letter B
# metric: Hell
# 45.15338867073517
#
# A: Transformation #2
# B: The letter A
# metric: Hell
# 0.25142730910979605
#
# A: Transformation #2
# B: The letter B
# metric: Hell
# 1.2634344823346402
#
# A: Transformation #3
# B: The letter A
# metric: Hell
# 51.968528856420946
#
# A: Transformation #3
# B: The letter B
# metric: Hell
# 54.17648535794012
#
# A: Transformation #4
# B: The letter A
# metric: Hell
# Error
#
# A: Transformation #4
# B: The letter B
# metric: Hell
# Error
#
# -----------------------
# A: Transformation #0
# B: The letter A
# metric: KL
# 35.547470161273395
#
# A: Transformation #0
# B: The letter B
# metric: KL
# 3092.310616489446
#
# A: Transformation #1
# B: The letter A
# metric: KL
# /Users/Jacky/Library/Python/3.6/lib/python/site-packages/ipykernel_launcher.py:69: RuntimeWarning: divide by zero encountered in double_scalars
# inf
#
# A: Transformation #1
# B: The letter B
# metric: KL
# inf
#
# A: Transformation #2
# B: The letter A
# metric: KL
# 330.4032758345892
#
# A: Transformation #2
# B: The letter B
# metric: KL
# 3101.118013368449
#
# A: Transformation #3
# B: The letter A
# metric: KL
# inf
#
# A: Transformation #3
# B: The letter B
# metric: KL
# inf
#
# A: Transformation #4
# B: The letter A
# metric: KL
# Error
#
# A: Transformation #4
# B: The letter B
# metric: KL
# Error
#
# -----------------------

# %%
f, axarr = plt.subplots(2, 3)
axarr[0, 0].imshow(base_images[0])
axarr[0, 1].imshow(transformsA[0])
axarr[0, 2].imshow(transformsA[1])
axarr[1, 0].imshow(transformsA[2])
axarr[1, 1].imshow(transformsA[3])
axarr[1, 2].imshow(transformsA[4])

# %%
draw_with_size(base_images[1], 3)
